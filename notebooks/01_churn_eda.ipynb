# %% [markdown]
# # Customer Churn Prediction — EDA + Model Benchmark
# Senior-style notebook for cleaning, exploratory analysis, model comparison and threshold tuning.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from pathlib import Path

df = pd.read_csv('../data/customer_churn.csv')
df.head()

# %%
df.shape
df.info()
df['Churn'].value_counts(normalize=True)

# %%
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')
sns.countplot(data=df, x='Churn')
plt.title('Customer Churn Distribution')
plt.show()

# %%
sns.boxplot(data=df, x='Churn', y='MonthlyCharges')
plt.title('Monthly Charges vs Churn')
plt.show()

# %% [markdown]
# ## Training
# The production training implementation is in `src/train.py`. It compares Logistic Regression and Random Forest using 5-fold out-of-fold probabilities, selects an F1-optimized threshold without touching the final test set, then evaluates the selected model once on the holdout set.
